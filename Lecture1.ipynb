# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# print("Addition",2+3)

# %%
a=5
b=8
print(a-b)
print(a+b)
# Out:
# -3
# 13

# %%
s=a+b
print(s)
# Out:
# 13

# %%
s=int(input("Enter any Number : "))
p=int(input("Enter second Number :"))
a=s+p
print("Sum of digit : ",a)
# Out:
# Enter any Number : 56
# Enter second Number :43
# Sum of digit :  99

# %%
a=int(input("Enter any Number :"))
b=int(input("Enter second Number :"))
c=int(input("Enter third Number :"))
d=a+b
e=a*c
g=a/b
f=b/c
h=b*c
print("Sum of digit :",d)
print("Mult. of digit :",e)
print("Divi. of digit :",g)
print("Divi. of digit :",f)
print("Mult. of digit :",h)
# Out:
# Enter any Number :2
# Enter second Number :3
# Enter third Number :4
# Sum of digit : 5
# Mult. of digit : 8
# Divi. of digit :%.2f 0.6666666666666666
# Divi. of digit : 0.75
# Mult. of digit : 12

# %%
a=50
b=25
print("before swapping :",a,b)
a,b=b,a
print("After swapping : ",a,b)
# Out:
# before swapping : 50 25
# After swapping :  25 50

# %%
#Assigment operators
a=3
b=2
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
print(a==b)
print(a!=b)

# logical operators
a=20
b=20
print(a is b)
print(a is not b)
print(id(a))
print(id(b))
# Out:
# True
# False
# True
# False
# False
# True
# True
# False
# 11645960
# 11645960

# %%
#membership operator
#in
#not
x=["apple","Banana"]
print("banana"in x)
print("banana" not in  x)
# Out:
# False
# True

# %%
#using else
a=int(input("Enter any Number :"))
if a>=18:
  print("You are eligible to vote")
else:
  print("You are not eligible to vote")
# Out:
# Enter any Number :16
# You are not eligible to vote

# %%
#print grading system
marks = int(input("Enter any number : "))
if marks>=90:
  print("Grad A")
if marks<=80:
  print("Grad B")
else:
  print("C")
# Out:
# Enter any number : 93
# Grad A
# C

# %%
#for loop
x=range(5)
for i in  x:
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
x=("GLA UNIVERSITY")
for  i in x:
  print(i)
# Out:
# G
# L
# A
#
# U
# N
# I
# V
# E
# R
# S
# I
# T
# Y

# %%
#whiel loop
i=1
while i<6:
  print(i)
  i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#printing table
n=int(input("Enter any number : "))
i=1
while i<=10:
  print(f"{n} X {i} = {n*i}")
  i+=1
# Out:
# Enter any number : 2
# 2 X 1 = 2
# 2 X 2 = 4
# 2 X 3 = 6
# 2 X 4 = 8
# 2 X 5 = 10
# 2 X 6 = 12
# 2 X 7 = 14
# 2 X 8 = 16
# 2 X 9 = 18
# 2 X 10 = 20

# %%
#String
name =("GLA UNIVERSITY")
print(name[0])
print(name[1])
print(name[0:3])
print(name[-1])
print(name[4])
print(name[-5:-1])
print(name[6])
# Out:
# G
# L
# GLA
# Y
# U
# RSIT
# I

# %%
#data structure in pythan
#list
#tuple
#dictionary
#set

# %%
#list
list=["kapil",21,"kumar","mathura",5.10,21]
print(list)
print(len(list))
# Out:
# ['kapil', 21, 'kumar', 'mathura', 5.1, 21]
# 6

# %%
print(list[3])
# Out:
# mathura

# %%
list.append("hello")
print(list)
# Out:
# ['kapil', 21, 'kumar', 'mathura', 5.1, 21, 'hello', 'hello', 'hello']

# %%
list.insert(2,"B.tech")
print(list)
# Out:
# ['kapil', 21, 'B.tech', 'B.tech', 'kumar', 'mathura', 5.1, 21, 'hello', 'hello', 'hello']

# %%
#tuple
a={1,2,3,4,5}
b={4,5,6,7,8}
print(a.difference(b))
print(a.union(b))
print(a.intersection(b))
# Out:
# {1, 2, 3}
# {1, 2, 3, 4, 5, 6, 7, 8}
# {4, 5}
